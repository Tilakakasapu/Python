# %%
#exception class as the base class creates a custom exception needed because 
#by inheriting from Exceptiion class your custoom exception becomes part of pythons exception heirarchy 
#exception class provides essential functionality common to all exceptions,such as ability to set an error message etc..

# %%
def print_exception_hierarchy(exception_class,indent=0):
    print(' '*indent +str(exception_class))
    for i in exception_class.__subclasses__():
        print_exception_hierarchy(i,indent+2)
if __name__ == "__main__":
    print_exception_hierarchy(BaseException)
# Out:
# <class 'BaseException'>
#   <class 'Exception'>
#     <class 'TypeError'>
#       <class 'decimal.FloatOperation'>
#       <class 'email.errors.MultipartConversionError'>
#     <class 'StopAsyncIteration'>
#     <class 'StopIteration'>
#     <class 'ImportError'>
#       <class 'ModuleNotFoundError'>
#       <class 'zipimport.ZipImportError'>
#     <class 'OSError'>
#       <class 'ConnectionError'>
#         <class 'BrokenPipeError'>
#         <class 'ConnectionAbortedError'>
#         <class 'ConnectionRefusedError'>
#         <class 'ConnectionResetError'>
#           <class 'http.client.RemoteDisconnected'>
#       <class 'BlockingIOError'>
#       <class 'ChildProcessError'>
#       <class 'FileExistsError'>
#       <class 'FileNotFoundError'>
#       <class 'IsADirectoryError'>
#       <class 'NotADirectoryError'>
#       <class 'InterruptedError'>
#         <class 'zmq.error.InterruptedSystemCall'>
#       <class 'PermissionError'>
#       <class 'ProcessLookupError'>
# ...

# %%
#FlotingPointError , OverFlowError,ZeroDivisionError are the errors defined in arthmatic error class 
#floating point error occuurs when a when a program tries to perform an action with floating numbers but encounters an issue that prevents the actionn to compete
big = 1.0e1000
b = big*2
print(b)
#here it gives inf as a result but it is not the exact ans this type of exceptions are floating poinn errors
10/0
#here we here we get a zero division eror  as we are trying to divide a number with 0
# Out:
# inf

# %%
#lookup error class is a base class for index error and key error
#keyerror occurs when we try to access a element in a dictionary that is not available in that dictionnary
d = {1:'one',2:'two'}
print(d[3])#keyerror
#index error occurs when you try to access an element in a list that is having a index grater than no of elements in the list
l = [1,2,3,4]
print(l[7])#index error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 4
#       1 #lookup error class is a base class for index error and key error
#       2 #keyerror occurs when we try to access a element in a dictionary that is not available in that dictionnary
#       3 d = {1:'one',2:'two'}
# ----> 4 print(d[3])#keyerror
#       5 #index error occurs when you try to access an element in a list that is having a index grater than no of elements in the list
#       6 l = [1,2,3,4]
#
# KeyError: 3

# %%
#import is used to import modules into your python file
#import error occurs when you are trying to import a modele that does not exist
#this is results in import error ModuleNotFoundError
import tilak
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 4
#       1 #import is used to import modules into your python file
#       2 #import error occurs when you are trying to import a modele that does not exist
#       3 #this is results in import error ModuleNotFoundError
# ----> 4 import tilak
#
# ModuleNotFoundError: No module named 'tilak'

# %%
#best use of exceptiion handling is use of best hierarchy
try: 
    10/0
except Exception as e:
    print(e)
#here we are managing the exception directly using the base Exception class this is not a good practise
try:
    f = open('tilak.txt','r')
    f.write("hi")
except AttributeError as e:
    print('got attribute error')
except NameError as e:
    print('got a name error',e)
except FileNotFoundError as e:
    print('got a file error',e)
except Exception as e:
    print('error',e)
#here we are manaigng a exeption a hierarcy so that the error can be managed in a good order
# Out:
# division by zero
# got a file error [Errno 2] No such file or directory: 'tilak.txt'
